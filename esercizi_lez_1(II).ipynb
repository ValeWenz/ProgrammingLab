# %%
import numpy as np
print("Numpy è installato correttamente!")
print(f"Versione: {np.__version__}")
# Out:
# Numpy è installato correttamente!
# Versione: 2.4.3

# %%
#esercizio 1
lista1=[]
for i in range(10):
    lista1.append(i)
lista1=[i for i in range(10)]
#----
lista2=[]
for i in range(10):
    lista2.append(i*i)
lista2=[i*i for i in range(10)]
#----
lista3=[]
for i in range(10):
    if(i%2==0): lista3.append(i)
lista3=[i for i in range(10) if i%2==0]

# %%
#esercizio 2
arr1=np.array([0,1,2,3,5,7])
#----
L=len(arr1)
K=arr1.size
#----
print(arr1.dtype)
#----
def is_prime(x):
    for i in range (2,x-1):
        if x%i==0: return False
    return True

arr_primi=np.array([x for x in range(0,10) if is_prime(x)])
# Out:
# int64

# %%
#esercizio 3
a=np.arange(1,20)
b=a[2:4]
c=a[::-1]
risultato=a/c
#----
listaA=list(range(2,10))
listaB=listaA[2:5]
listaC=listaA[::-1]
risultato_lista = [listaA[i] / listaC[i] for i in range(len(listaA))]
