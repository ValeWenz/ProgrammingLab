# %%
import numpy as np
print("Numpy è installato correttamente!")
print(f"Versione: {np.__version__}")
# Out:
# Numpy è installato correttamente!
# Versione: 2.4.3

# %%
#esercizio 1
vett=np.array([2,3,5,7,11,13,17,19])
#----
vett[vett>10]
#----
vett[vett%2==0]

# %%
#esercizio 2
a=np.arange(1,21).reshape(4,5)
#----
b=a[[1,3], ]
c=a[[2], ]
#----
risultato_array= a/c

# %%
#esercizio 3
ARR=np.random.rand(10,3)
c=np.argmin(np.abs(ARR-0.5), axis=1)
ARR[np.arange(ARR.shape[0]),np.argmin(np.abs(ARR-0.5), axis=1)]
# Out:
# array([0.42091496, 0.56123185, 0.560251  , 0.61088828, 0.47558877,
#        0.26270558, 0.65194552, 0.45420155, 0.63466191, 0.18971302])
