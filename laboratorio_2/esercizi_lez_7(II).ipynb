# %%
#esercizio 1
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

#Genera 1000 valori casuali da una distribuzione gamma con parametro di forma pari a 1. Suggerimento: il parametro di forma viene passato come primo argomento quando si "congela" la distribuzione.
dist=sp.stats.gamma(a=1)
sample=dist.rvs(size=1000)

#traccia l’istogramma del campione e sovrapponi la PDF della distribuzione.
plt.hist(sample, bins=50, density=True)

x=np.linspace(0,10)
plt.plot(x, dist.pdf(x))

#Stima il parametro di forma dal campione usando il metodo fit.
sp.stats.gamma.fit(sample)

#Extra: Le distribuzioni hanno molti metodi utili. Esplorali usando il completamento automatico con il tasto TAB.

#Traccia la funzione di distribuzione cumulativa (CDF).
cdf=dist.cdf(x)
plt.plot(x, cdf)

#Calcola la varianza.
varianza=np.var(sample)
print(f"varianza: {varianza}")
# Out:
# varianza: 1.137792396658744

# %%
#esercizio 2
#Prova a fittare i dati sottostanti con le migliori curve, calcola il MAE e l'RMSE Esercizio
import numpy as np
temp_max = np.array([17, 19, 21, 28, 33, 38, 37, 37, 31, 23, 19, 18])
temp_min = np.array([-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58])
import matplotlib.pyplot as plt

months=np.arange(12)
plt.plot(months, temp_max, "ro")
plt.plot(months,temp_min,"ro",color="blue")

def polinomio_grado_3(x,a,b,c,d):
    return a*x**3 + b*x**2 + c*x +d

def sin(x,a,b,c):
    return c+a*np.sin((x+b)*2*np.pi/12)

params_MAX, _ = sp.optimize.curve_fit(sin, months, temp_max)
params_MIN, _ = sp.optimize.curve_fit(sin, months, temp_min)

x=np.linspace(0,11)
plt.plot(x,sin(x,*params_MAX))
plt.plot(months,temp_max, "ro")

plt.plot(months,temp_max, "ro")
plt.plot(x,sin(x,*params_MIN))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16812\901197248.py:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(months,temp_min,"ro",color="blue")

# %%
#esercizio 3
import pandas as pd

# Load dataset from URL
df = pd.read_csv('https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv')

# Display the dataframe
df
x=df["disp"]
y=df["mpg"]

#Calcola un modello di regressione lineare delle colonne mpg e disp del famoso dataset mtcars.
slope, intercept, *_ = sp.stats.linregress(x,y)

y_pred=slope*x + intercept

#plt.plot(x,y, label="label ")
plt.plot(x, y_pred)
plt.show()
