# %% [markdown]
# ##INIZIAMO##
#
# ciao Sam, qua solo testo

# %%
print("Hello World, e ciao Sam")
# Out:
# Hello World, e ciao Sam

# %%
# %timeit lista=[n*n for n in range(200)]
#con la list comprehension sta meno tempo
# Out:
# 7.21 μs ± 99.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit
lista=[]
for n in range(200):
    lista.append(n*n)

#su più righe, sta più tempo
# Out:
# 8.76 μs ± 132 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
#chissà: è !ls o ls? non so se lo sapremo mai

# %%
import numpy as np
print("Numpy è installato correttamente!")
print(f"Versione: {np.__version__}")
# Out:
# Numpy è installato correttamente!
# Versione: 2.4.3
